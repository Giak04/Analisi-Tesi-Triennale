# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from pathlib import Path
import numpy as np
from decimal import Decimal

from scipy.optimize import curve_fit

import astropy.units as u
from astropy.coordinates import Angle, SkyCoord, EarthLocation, AltAz
from astropy.time import Time
from astropy.table import Table

import warnings

# %%
# Open the file
filename="/Users/saveriolombardi/Astri_Analyses/hands-on/IN/data/20250130_MA01_Crab_W0.50p090_00000951_R_001909_0201.lv1c.fits"
extension = "EVENTS"
file = Table.read(filename, hdu=extension)
file
# Out:
# WARNING: UnitsWarning: 'pe' did not parse as fits unit: At col 0, Unit 'pe' not supported by the FITS standard. Did you mean PeV or peV? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'pe' did not parse as fits unit: At col 0, Unit 'pe' not supported by the FITS standard. Did you mean PeV or peV? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# <Table length=145015>
#   VT        TIME_UTC        TIME_S  ...    DISP       XDISP      YDISP
#                               s     ...    deg         deg        deg
# ...

# %%
# Make an histogram
parameter="GAMMANESS"
cuts=(file["SIZE"]>200) & (file["LEAKAGE"]<0.1)
plt.hist(file[parameter][cuts], bins=50, color='skyblue', edgecolor='black')
plt.ylabel("N#")
plt.xlabel(parameter)
plt.semilogy()
# Out:
# []

# %%
# Make a 2D histogram
parameter1="MEANX"
parameter2="MEANY"
cuts2=(file["SIZE"]>50) & (file["SIZE"]<100)
plt.hist2d(file[parameter1][cuts2], file[parameter2][cuts2], bins=(200,200))
plt.xlabel(parameter1)
plt.ylabel(parameter2)
# Out:
# Text(0, 0.5, 'MEANY')

# %%
# Make a scatter plot
parameter1="SIZE"
parameter2="EST_EN"
cuts2=(file["SIZE"]>100) & (file["LEAKAGE"]<0.1) & (file["GAMMANESS"]>0.5)
plt.plot(file[parameter1][cuts2], file[parameter2][cuts2],"+") #use `+,o,*` for points or `-` for lines
plt.xlabel(parameter1)
plt.ylabel(parameter2)
plt.semilogx()
# Out:
# []
